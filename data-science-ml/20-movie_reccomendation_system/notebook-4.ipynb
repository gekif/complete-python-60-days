# %% [markdown]
# # Collaborative-Based Filtering

# %% [markdown]
# ## Load Data

# %%
import pandas as pd

ratings = pd.read_csv("data/ratings.csv")[["userId", "movieId", "rating"]]
ratings.head()
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]

# %% [markdown]
# ## Create the Dataset

# %%
from surprise import Dataset, Reader

reader = Reader(rating_scale(1,5))
dataset = Dataset.load_from_df(ratings)
dataset

# %% [markdown]
# ## Build the Trainset

# %%
trainset = dataset.build_full_trainset()
trainset

# %%
list(trainset.all_ratings())

# %%
## Train the Model

# %%
from surprise import SVD

svd = SVD()

# %%
svd.fit(trainset)

# %%
svd.predict(15, 1956)

# %% [markdown]
# ## Validation

# %%
from suprise import model_selection

model_selection.cross_validate(svd, dataset, measures=['RMSE', 'MAE'])
